# %% [markdown]
# For two strings s and t, we say "t divides s" if and only if s = t + t + t + ... + t + t (i.e., t is concatenated with itself one or more times).
#
# Given two strings str1 and str2, return the largest string x such that x divides both str1 and str2.
#
#
#
# Example 1:
#
# Input: str1 = "ABCABC", str2 = "ABC"
# Output: "ABC"
# Example 2:
#
# Input: str1 = "ABABAB", str2 = "ABAB"
# Output: "AB"
# Example 3:
#
# Input: str1 = "LEET", str2 = "CODE"
# Output: ""
#
#
# Constraints:
#
# 1 <= str1.length, str2.length <= 1000
# str1 and str2 consist of English uppercase letters.

# %%
import math
class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:
        
        gcd_length = math.gcd(len(str1), len(str2))

        candidate = str1[:gcd_length]

        def is_divisible(s: str, t: str) -> bool:
            if len(t) == 0:
                return False
            return s == t * (len(s) // len(t))
        
        if is_divisible(str1, candidate) and is_divisible(str2, candidate):
            return candidate
        else:
            return ""

# %%
##WayBetter

class Solution:
    def gcdOfStrings(self, str1: str, str2: str) -> str:

        if str1+str2 != str2+str1:
            return ""
        
        def gcd(a: int, b: int) -> int:
            while b:
                a, b = b, a % b
            return a

        gcd_length = gcd(len(str1), len(str2))
        return str1[:gcd_length]

# %%
def main():
    # Create an instance of the Solution class
    solution = Solution()
    
    # Define test cases
    test_cases = [
        ("ABCABC", "ABC"),
        ("ABABAB", "ABAB"),
        ("LEET", "CODE"),
        ("ABCDEF", "ABC"),
        ("AAAAAAAAAA", "AAAAAA"),
    ]
    
    # Iterate over test cases and print results
    for str1, str2 in test_cases:
        result = solution.gcdOfStrings(str1, str2)
        print(f"gcdOfStrings('{str1}', '{str2}') = '{result}'")

if __name__ == "__main__":
    main()
# Out:
# gcdOfStrings('ABCABC', 'ABC') = 'ABC'
# gcdOfStrings('ABABAB', 'ABAB') = 'AB'
# gcdOfStrings('LEET', 'CODE') = ''
# gcdOfStrings('ABCDEF', 'ABC') = ''
# gcdOfStrings('AAAAAAAAAA', 'AAAAAA') = 'AA'

# %%
def run_test_cases():
    solution = Solution()

    # Define test cases
    test_cases = [
            ("ABCABC", "ABC", "ABC"),
            ("ABABAB", "ABAB", "AB"),
            ("LEET", "CODE", ""),
            ("ABCDEF", "ABC", ""),
            ("AAAAAAAAAA", "AAAAAA", "AA"),
            ("XYZXYZ", "XYZ", "XYZ"),
            ("", "", ""),
            ("A", "A", "A"),
            ("AAABBB", "AAABB", ""),
        ]

    # Run test cases
    for i, (str1, str2, expected) in enumerate(test_cases, 1):
        result = solution.gcdOfStrings(str1, str2)
        print(f"Test Case {i}:")
        print(f"Input: str1 = '{str1}', str2 = '{str2}'")
        print(f"Expected Output: '{expected}'")
        print(f"Actual Output:   '{result}'")
        print()

if __name__ == "__main__":
    run_test_cases()
# Out:
# Test Case 1:
# Input: str1 = 'ABCABC', str2 = 'ABC'
# Expected Output: 'ABC'
# Actual Output:   'ABC'
#
# Test Case 2:
# Input: str1 = 'ABABAB', str2 = 'ABAB'
# Expected Output: 'AB'
# Actual Output:   'AB'
#
# Test Case 3:
# Input: str1 = 'LEET', str2 = 'CODE'
# Expected Output: ''
# Actual Output:   ''
#
# Test Case 4:
# Input: str1 = 'ABCDEF', str2 = 'ABC'
# Expected Output: ''
# Actual Output:   ''
#
# Test Case 5:
# Input: str1 = 'AAAAAAAAAA', str2 = 'AAAAAA'
# Expected Output: 'AA'
# Actual Output:   'AA'
#
# Test Case 6:
# Input: str1 = 'XYZXYZ', str2 = 'XYZ'
# Expected Output: 'XYZ'
# Actual Output:   'XYZ'
#
# Test Case 7:
# Input: str1 = '', str2 = ''
# Expected Output: ''
# Actual Output:   ''
#
# Test Case 8:
# Input: str1 = 'A', str2 = 'A'
# Expected Output: 'A'
# Actual Output:   'A'
#
# Test Case 9:
# Input: str1 = 'AAABBB', str2 = 'AAABB'
# Expected Output: ''
# Actual Output:   ''
