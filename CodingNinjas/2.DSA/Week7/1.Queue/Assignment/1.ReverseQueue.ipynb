# %%
# Using Recursion

# Without Recursion Using Another Data Structure
from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

def reverseQueue(inputQueue) :
    # Your code goes here
    if inputQueue.qsize() == 0:
        return
        
    front = inputQueue.get()
    reverseQueue(inputQueue)
    inputQueue.put(front)


'''-------------- Utility Functions --------------'''



def takeInput():
    n = 6

    qu = queue.Queue()
    values = list(map(int, input().strip().split()))

    for i in range(n) :
        qu.put(values[i])

    return qu

qu = takeInput()
reverseQueue(qu)

while not qu.empty():
    print(qu.get(), end = ' ')

# %%
# Without Recursion Using Another Data Structure
from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

def reverseQueue(inputQueue) :
    # Your code goes here
    stack = []
    while inputQueue.qsize():
        stack.append(inputQueue.get())

    while len(stack):
        inputQueue.put(stack[-1])
        stack.pop()

    while inputQueue:
        print(inputQueue.get(), end = ' ')





'''-------------- Utility Functions --------------'''



def takeInput():
    n = int(input().strip())

    qu = queue.Queue()
    values = list(map(int, input().strip().split()))

    for i in range(n) :
        qu.put(values[i])

    return qu

qu = takeInput()
reverseQueue(qu)
